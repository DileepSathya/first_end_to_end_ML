# %%
import pandas as pd

df1=pd.read_csv(r"C:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\artifacts\feature_engineering\scaled_data\scaled_train.csv")
df2=pd.read_csv(r"C:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\artifacts\feature_engineering\scaled_data\scaled_test.csv")
df=pd.concat([df1,df2])
df.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0    0.052632            0.0              1.00       0.026201        0.000000
# 1    0.026316            0.0              0.75       0.001754        0.000000
# 2    0.131579            0.0              0.75       0.001818        0.100000
# 3    0.078947            0.0              0.25       0.029399        0.000000
# 4    0.105263            1.0              1.00       0.023819        0.033333
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0               1.000000   1.000000          0.8       0.727023
# 1               0.666667   0.014493          0.2       0.392318
# 2               0.000000   0.144928          0.6       0.510974
# 3               1.000000   1.000000          0.6       0.672840
# 4               1.000000   1.000000          0.6       0.606996
#
#    loan_percent_income  credit_score  previous_loan_defaults_on_file  \
# ...

# %%
from sklearn.model_selection import train_test_split
def tts(stat):
    train,test=train_test_split(df,test_size=0.2,shuffle=stat)

    print(test.shape,train.shape)

tts(False)
# Out:
# (8954, 13) (35814, 13)
