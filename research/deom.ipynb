# %%
import pandas as pd
from pathlib import Path

# %%
file_path=Path("artifacts/data_ingestion/data/loan_data.csv")
print(file_path)
# Out:
# artifacts\data_ingestion\data\loan_data.csv

# %%
df = pd.read_csv(r"C:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\artifacts\data_ingestion\data\loan_data.csv")

df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df['person_age'].describe()
# Out:
# count    45000.000000
# mean        27.764178
# std          6.045108
# min         20.000000
# 25%         24.000000
# 50%         26.000000
# 75%         30.000000
# max        144.000000
# Name: person_age, dtype: float64

# %% [markdown]
# # Report
# seems like the persons age was not valid so if age greater than 80 should be removed

# %%
x=df[df['person_age']>80]
x
# Out:
#        person_age person_gender person_education  person_income  \
# 81          144.0          male         Bachelor       300616.0
# 183         144.0          male        Associate       241424.0
# 575         123.0        female      High School        97140.0
# 747         123.0          male         Bachelor        94723.0
# 32297       144.0        female        Associate      7200766.0
# 32416        94.0          male      High School        29738.0
# 32506        84.0          male      High School       114705.0
# 37930       116.0          male         Bachelor      5545545.0
# 38113       109.0          male      High School      5556399.0
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 81                125                  RENT     4800.0     VENTURE
# 183               121              MORTGAGE     6000.0   EDUCATION
# 575               101                  RENT    20400.0   EDUCATION
# ...

# %% [markdown]
# above is the data frmae com=ntaining age >80
#
# below code will only save the df with age <=80

# %%
df = df[df['person_age'] <= 80]
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df['person_gender'].value_counts()
# Out:
# person_gender
# male      24834
# female    20157
# Name: count, dtype: int64

# %%
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13396
# Associate      12026
# High School    11968
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['person_income'].describe()
# Out:
# count    4.499100e+04
# mean     7.990879e+04
# std      6.332289e+04
# min      8.000000e+03
# 25%      4.719650e+04
# 50%      6.704600e+04
# 75%      9.577600e+04
# max      2.448661e+06
# Name: person_income, dtype: float64

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df['person_emp_exp'].describe()
# Out:
# count    44991.000000
# mean         5.391723
# std          5.912127
# min          0.000000
# 25%          1.000000
# 50%          4.000000
# 75%          8.000000
# max         62.000000
# Name: person_emp_exp, dtype: float64

# %%
df[df['person_emp_exp']>20]
# Out:
#        person_age person_gender person_education  person_income  \
# 29121        50.0          male      High School      1081082.0
# 29124        45.0          male           Master        96924.0
# 29127        44.0          male      High School       703125.0
# 29131        43.0        female           Master       600812.0
# 29139        46.0          male         Bachelor       404111.0
# ...           ...           ...              ...            ...
# 44887        44.0          male        Associate        74199.0
# 44916        42.0        female      High School       100310.0
# 44923        47.0          male        Associate        46637.0
# 44947        42.0          male        Doctorate       705960.0
# 44977        43.0          male        Associate        22639.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29121              28              MORTGAGE    30000.0  DEBTCONSOLIDATION
# ...

# %%
df[df['person_emp_exp']>25]
# Out:
#        person_age person_gender person_education  person_income  \
# 29121        50.0          male      High School      1081082.0
# 29182        50.0        female        Associate       240876.0
# 29193        47.0          male        Associate        67887.0
# 29200        44.0        female        Associate       229542.0
# 29220        47.0        female      High School       108864.0
# ...           ...           ...              ...            ...
# 44209        45.0        female      High School       127065.0
# 44220        60.0          male         Bachelor        55787.0
# 44702        55.0        female        Associate        68221.0
# 44703        45.0          male        Associate        33267.0
# 44705        52.0        female         Bachelor        59758.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29121              28              MORTGAGE    30000.0  DEBTCONSOLIDATION
# ...

# %%
df[df['person_emp_exp']>30]
# Out:
#        person_age person_gender person_education  person_income  \
# 29182        50.0        female        Associate       240876.0
# 29877        50.0          male        Associate        49258.0
# 31021        50.0          male        Associate        73079.0
# 31319        49.0        female        Associate        90896.0
# 31667        50.0          male      High School       145232.0
# ...           ...           ...              ...            ...
# 42856        56.0          male      High School        62424.0
# 43244        59.0          male        Associate        45292.0
# 43838        61.0          male        Associate        73448.0
# 44220        60.0          male         Bachelor        55787.0
# 44702        55.0        female        Associate        68221.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29182              31                  RENT     7000.0           PERSONAL
# ...

# %%
df=df[df['person_emp_exp']<=30]
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23307
# MORTGAGE    18407
# OWN          2937
# OTHER         117
# Name: count, dtype: int64

# %%
df=df[df['person_home_ownership']!="OTHER"]
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df['loan_amnt'].describe()
# Out:
# count    44651.000000
# mean      9574.963875
# std       6311.314056
# min        500.000000
# 25%       5000.000000
# 50%       8000.000000
# 75%      12200.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9113
# MEDICAL              8487
# VENTURE              7770
# PERSONAL             7430
# DEBTCONSOLIDATION    7099
# HOMEIMPROVEMENT      4752
# Name: count, dtype: int64

# %%
df['loan_int_rate'].describe()
# Out:
# count    44651.000000
# mean        11.004012
# std          2.979208
# min          5.420000
# 25%          8.590000
# 50%         11.010000
# 75%         12.990000
# max         20.000000
# Name: loan_int_rate, dtype: float64

# %%
df=df.drop(columns=["cb_person_cred_hist_length","loan_percent_income"],axis=1)
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  credit_score  \
# 0                  RENT    35000.0    PERSONAL          16.02           561
# 1                   OWN     1000.0   EDUCATION          11.14           504
# 2              MORTGAGE     5500.0     MEDICAL          12.87           635
# 3                  RENT    35000.0     MEDICAL          15.23           675
# 4                  RENT    35000.0     MEDICAL          14.27           586
#
#   previous_loan_defaults_on_file  loan_status
# ...

# %%
df['credit_score'].describe()
# Out:
# count    44651.000000
# mean       632.351168
# std         50.294229
# min        390.000000
# 25%        601.000000
# 50%        639.000000
# 75%        669.000000
# max        768.000000
# Name: credit_score, dtype: float64

# %%
df['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# Yes    22729
# No     21922
# Name: count, dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    34747
# 1     9904
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44651 entries, 0 to 44999
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      44651 non-null  float64
#  1   person_gender                   44651 non-null  object
#  2   person_education                44651 non-null  object
#  3   person_income                   44651 non-null  float64
#  4   person_emp_exp                  44651 non-null  int64
#  5   person_home_ownership           44651 non-null  object
#  6   loan_amnt                       44651 non-null  float64
#  7   loan_intent                     44651 non-null  object
#  8   loan_int_rate                   44651 non-null  float64
#  9   credit_score                    44651 non-null  int64
#  10  previous_loan_defaults_on_file  44651 non-null  object
#  11  loan_status                     44651 non-null  int64
# ...

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  credit_score  \
# 0                  RENT    35000.0    PERSONAL          16.02           561
# 1                   OWN     1000.0   EDUCATION          11.14           504
# 2              MORTGAGE     5500.0     MEDICAL          12.87           635
# 3                  RENT    35000.0     MEDICAL          15.23           675
# 4                  RENT    35000.0     MEDICAL          14.27           586
#
#   previous_loan_defaults_on_file  loan_status
# ...

# %%
x=df.drop(columns=['loan_status'])
y=df['loan_status']
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (35720, 11) (35720,) (8931, 11) (8931,)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize a nested dictionary to store mappings for all columns
mappings = {}

# Identify categorical columns
categorical_list = [col for col in x_train.columns if x_train[col].dtype == 'object']

# Encode each categorical column
for col in categorical_list:
    le = LabelEncoder()  # Create a new LabelEncoder for each column
    x_train[col] = le.fit_transform(x_train[col])
    x_test[col] = le.transform(x_test[col])
    
    # Store both mappings (forward in the nested dictionary
    mappings[col] = {v:int(k) for k, v in zip(le.transform(le.classes_), le.classes_)}


# Print the nested dictionary with mappings for each column
print(mappings)

# Display the first 10 rows of the encoded training data
x_train.head(10)
# Out:
# {'person_gender': {'female': 0, 'male': 1}, 'person_education': {'Associate': 0, 'Bachelor': 1, 'Doctorate': 2, 'High School': 3, 'Master': 4}, 'person_home_ownership': {'MORTGAGE': 0, 'OWN': 1, 'RENT': 2}, 'loan_intent': {'DEBTCONSOLIDATION': 0, 'EDUCATION': 1, 'HOMEIMPROVEMENT': 2, 'MEDICAL': 3, 'PERSONAL': 4, 'VENTURE': 5}, 'previous_loan_defaults_on_file': {'No': 0, 'Yes': 1}}
#        person_age  person_gender  person_education  person_income  \
# 199          22.0              0                 1        18152.0
# 35931        24.0              1                 3        51408.0
# 31407        46.0              1                 1       111253.0
# 17231        22.0              1                 3        73682.0
# 2739         21.0              0                 0        41365.0
# 34429        25.0              1                 1        72979.0
# 39151        28.0              0                 1       168633.0
# ...

# %%
x_test.head(10)
# Out:
#        person_age  person_gender  person_education  person_income  \
# 39730        30.0              0                 1        31658.0
# 18348        27.0              1                 4        68532.0
# 16930        22.0              1                 1        66070.0
# 357          22.0              1                 4        20297.0
# 10131        23.0              0                 3        27334.0
# 29270        48.0              0                 0       156972.0
# 43044        26.0              0                 3        59836.0
# 38875        27.0              1                 1       106509.0
# 37692        33.0              0                 1       168679.0
# 30955        37.0              1                 0        86284.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 39730               8                      1    13595.0            5
# 18348               3                      2    20000.0            2
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35720 entries, 199 to 15861
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      35720 non-null  float64
#  1   person_gender                   35720 non-null  int64
#  2   person_education                35720 non-null  int64
#  3   person_income                   35720 non-null  float64
#  4   person_emp_exp                  35720 non-null  int64
#  5   person_home_ownership           35720 non-null  int64
#  6   loan_amnt                       35720 non-null  float64
#  7   loan_intent                     35720 non-null  int64
#  8   loan_int_rate                   35720 non-null  float64
#  9   credit_score                    35720 non-null  int64
#  10  previous_loan_defaults_on_file  35720 non-null  int64
# dtypes: float64(4), int64(7)
# memory usage: 3.3 MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 35720 entries, 199 to 15861
# Series name: loan_status
# Non-Null Count  Dtype
# --------------  -----
# 35720 non-null  int64
# dtypes: int64(1)
# memory usage: 558.1 KB

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled_data=scaler.fit_transform(x_train)
type(scaled_data)
# Out:
# numpy.ndarray

# %%
scaled_data_test=scaler.transform(x_test)
scaled_data_test.shape
# Out:
# (8931, 11)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

model=rfc.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.923412831709775
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      6926
#            1       0.87      0.78      0.82      2005
#
#     accuracy                           0.92      8931
#    macro avg       0.90      0.87      0.89      8931
# weighted avg       0.92      0.92      0.92      8931

# %%
scaled_data.shape
# Out:
# (35720, 11)

# %%
scaled_data[2,]
# Out:
# array([0.68421053, 1.        , 0.25      , 0.06244259, 0.8       ,
#        0.        , 0.36014493, 0.2       , 0.38340192, 0.78571429,
#        1.        ])

# %%
print(y_train)
# Out:
# 199      1
# 35931    0
# 31407    0
# 17231    0
# 2739     1
#         ..
# 6293     1
# 11330    0
# 38493    0
# 867      0
# 15861    0
# Name: loan_status, Length: 35720, dtype: int64

# %%
x_train.head(199)
# Out:
#        person_age  person_gender  person_education  person_income  \
# 199          22.0              0                 1        18152.0
# 35931        24.0              1                 3        51408.0
# 31407        46.0              1                 1       111253.0
# 17231        22.0              1                 3        73682.0
# 2739         21.0              0                 0        41365.0
# ...           ...            ...               ...            ...
# 29439        45.0              0                 3        33430.0
# 44089        22.0              1                 0        15307.0
# 11707        26.0              1                 1        90665.0
# 16723        25.0              0                 3       108911.0
# 4832         22.0              0                 0        51566.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 199                 0                      1     4000.0            3
# ...

# %%
y_train.head(199)
# Out:
# 199      1
# 35931    0
# 31407    0
# 17231    0
# 2739     1
#         ..
# 29439    1
# 44089    1
# 11707    0
# 16723    0
# 4832     0
# Name: loan_status, Length: 199, dtype: int64

# %%
x_train
# Out:
#        person_age  person_gender  person_education  person_income  \
# 199          22.0              0                 1        18152.0
# 35931        24.0              1                 3        51408.0
# 31407        46.0              1                 1       111253.0
# 17231        22.0              1                 3        73682.0
# 2739         21.0              0                 0        41365.0
# ...           ...            ...               ...            ...
# 6293         26.0              1                 2        40571.0
# 11330        25.0              1                 0        69462.0
# 38493        24.0              1                 3       123299.0
# 867          25.0              1                 1       210999.0
# 15861        24.0              1                 3       163372.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 199                 0                      1     4000.0            3
# ...

# %%
cols=list(x_train.columns)

# %%
cols
# Out:
# ['person_age',
#  'person_gender',
#  'person_education',
#  'person_income',
#  'person_emp_exp',
#  'person_home_ownership',
#  'loan_amnt',
#  'loan_intent',
#  'loan_int_rate',
#  'credit_score',
#  'previous_loan_defaults_on_file']

# %%
len(cols)
# Out:
# 11

# %%
input_array = [None] * len(cols)

for i in range(len(cols)):
    print(cols[i])
    # Prompt for input and convert it to an integer
    input_array[i] = input("Enter value of " + cols[i] + ": ")

# Output the collected input values
print("Input Array:", input_array)
# Out:
# person_age
# person_gender
# person_education
# person_income
# person_emp_exp
# person_home_ownership
# loan_amnt
# loan_intent
# loan_int_rate
# credit_score
# previous_loan_defaults_on_file
# Input Array: ['', '', '', '', '', '', '', '', '', '', '']

# %%
mappings
# Out:
# {'person_gender': {'female': 0, 'male': 1},
#  'person_education': {'Associate': 0,
#   'Bachelor': 1,
#   'Doctorate': 2,
#   'High School': 3,
#   'Master': 4},
#  'person_home_ownership': {'MORTGAGE': 0, 'OWN': 1, 'RENT': 2},
#  'loan_intent': {'DEBTCONSOLIDATION': 0,
#   'EDUCATION': 1,
#   'HOMEIMPROVEMENT': 2,
#   'MEDICAL': 3,
#   'PERSONAL': 4,
#   'VENTURE': 5},
#  'previous_loan_defaults_on_file': {'No': 0, 'Yes': 1}}

# %%
import numpy as np
data=[12, 'female', 'Bachelor', 120000, 10, 'OWN', 100000, 'EDUCATION', 12, 300, 'Yes']

# %%
len(data)
# Out:
# 11

# %%
cat_list=[]
for i in data:
    if isinstance(i, str):
        cat_list.append(i)
cat_list
# Out:
# ['female', 'Bachelor', 'OWN', 'EDUCATION', 'Yes']

# %%
x=le.transform(cat_list)
x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\venv\lib\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File c:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\venv\lib\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File c:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\venv\lib\site-packages\sklearn\utils\_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# ...
