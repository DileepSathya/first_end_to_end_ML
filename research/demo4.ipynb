# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Dileep Sathya\OneDrive\Desktop\MLOPS\first_end_to_end_ML\artifacts\data_ingestion\data\loan_data.csv")

df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
#call this function to delete the data
def del_data(col_name,data,thres_value):
    data = data[data[col_name] <= thres_value]
    return data

df=del_data('person_age',df,80)

# %%
df[df['person_age']>80]
# Out:
# Empty DataFrame
# Columns: [person_age, person_gender, person_education, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %%
def col_delete(col_name,data):
    data=data.drop(columns=[col_name],axis=1)
    return data
df=col_delete('cb_person_cred_hist_length',df)
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
from src.MLOPS import logger
from src.MLOPS.utils.common import read_yaml,file_creation
from src.MLOPS.constants import *
def data_transformation_config():
        yaml_file=read_yaml(CONFIG_FILE_PATH)
        return yaml_file
data_transformation_config()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       5         yaml_file=read_yaml(CONFIG_FILE_PATH)
#       6         return yaml_file
# ----> 7 data_transformation_config()
#
# Cell In[1], line 5, in data_transformation_config()
#       4 def data_transformation_config():
# ----> 5         yaml_file=read_yaml(CONFIG_FILE_PATH)
#       6         return yaml_file
#
# File c:\users\dileep sathya\onedrive\desktop\mlops\first_end_to_end_ml\src\MLOPS\utils\common.py:33, in read_yaml(yaml_path)
#      31         return content
#      32 except Exception as e:
# ---> 33     raise e
#
# File c:\users\dileep sathya\onedrive\desktop\mlops\first_end_to_end_ml\src\MLOPS\utils\common.py:28, in read_yaml(yaml_path)
#      25 def read_yaml(yaml_path):
#      27     try:
# ---> 28         with open(yaml_path) as yaml_file:
# ...
